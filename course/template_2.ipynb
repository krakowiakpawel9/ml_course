# %% [markdown]
# <a href="https://colab.research.google.com/github/krakowiakpawel9/ml_course/blob/master/course/template_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### scikit-learn
# Website: [https://scikit-learn.org/](https://scikit-learn.org/)

# %%
# !pip install --upgrade scikit-learn

# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(42)
sns.set(font_scale=1.5)

sklearn.__version__
# Out:
# '0.22'

# %%
from sklearn.datasets import make_regression

data, target = make_regression(n_samples=100, n_features=1, n_targets=1, noise=20.0)

# %%
data[:10]
# Out:
# array([[ 0.93128012],
#        [ 0.08704707],
#        [-1.05771093],
#        [ 0.31424733],
#        [-0.47917424],
#        [ 0.64768854],
#        [-0.46341769],
#        [ 0.54256004],
#        [ 0.61167629],
#        [ 1.0035329 ]])

# %%
target[:10]
# Out:
# array([ 62.687202  , -23.76398073, -25.68676582,   7.93645654,
#        -15.47549454,  36.09395877, -40.79420109, -10.82303923,
#         21.41470699,  22.79862212])

# %%
plt.scatter(data, target)

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(data, target)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
regressor.score(data, target)
# Out:
# 0.8531542073179821

# %%
regressor.coef_
# Out:
# array([47.13323967])

# %%
regressor.intercept_
# Out:
# 2.3302306410539444

# %%
plt.scatter(data, target)
plt.plot(data, regressor.intercept_ + regressor.coef_ * data, color='red')
plt.show()

# %%
x1 = np.array([1, 2, 3, 4, 5, 6])
y1 = 2750 + 250 * x1

x2 = np.array([0, 1, 2, 3, 4, 5, 6, 7])
y2 = 2750 + 250 * x2

plt.figure(figsize=(10, 8))
plt.title('pensja vs. lata pracy')
plt.scatter(x1, y1, s=100)
# plt.plot(x2, y2, color='red')
plt.ylim(2700, 4500)
plt.xlim(0, 7)
plt.show()

# %%
x1 = np.array([1, 2, 3, 4, 5, 6])
y1 = np.array([3000, 3150, 3650, 3600, 4150, 4250])

x2 = np.array([0, 1, 2, 3, 4, 5, 6, 7])
y2 = 2750 + 250 * x2

plt.figure(figsize=(10, 8))
plt.title('pensja vs. lata pracy')
plt.scatter(x1, y1, s=100)
plt.plot(x2, y2, color='red')
plt.ylim(2700, 4500)
plt.xlim(0, 7)
plt.show()
