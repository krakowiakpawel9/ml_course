# %% [markdown]
# <a href="https://colab.research.google.com/github/krakowiakpawel9/ml_course/blob/master/unsupervised/03_association_rules/02_apriori.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### scikit-learn
# Strona biblioteki: [https://scikit-learn.org](https://scikit-learn.org)
#
# Dokumentacja/User Guide: [https://scikit-learn.org/stable/user_guide.html](https://scikit-learn.org/stable/user_guide.html)
#
# Podstawowa biblioteka do uczenia maszynowego w języku Python.
#
# Aby zainstalować bibliotekę scikit-learn, użyj polecenia poniżej:
# ```
# !pip install scikit-learn
# ```
# Aby zaktualizować do najnowszej wersji bibliotekę scikit-learn, użyj polecenia poniżej:
# ```
# !pip install --upgrade scikit-learn
# ```
# Kurs stworzony w oparciu o wersję `0.22.1`
#
# ### Spis treści:
# 1. [Import bibliotek](#0)
# 2. [Wygenerowanie danych](#1)
# 3. [Wizualizacja danych](#2)
# 4. [Algorytm K-średnich](#3)
# 5. [Wizualizacja klastrów](#4)

# %% [markdown]
# ### <a name='0'></a> Import bibliotek

# %%
# !wget https://storage.googleapis.com/esmartdata-courses-files/ml-course/products.csv
# !wget https://storage.googleapis.com/esmartdata-courses-files/ml-course/orders.csv
# Out:
# --2020-02-07 12:02:10--  https://storage.googleapis.com/esmartdata-courses-files/ml-course/products.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.203.128, 2404:6800:4008:c05::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.203.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2166953 (2.1M) [application/octet-stream]
# Saving to: ‘products.csv’
#
# products.csv        100%[===================>]   2.07M  --.-KB/s    in 0.008s
#
# 2020-02-07 12:02:12 (250 MB/s) - ‘products.csv’ saved [2166953/2166953]
#
# --2020-02-07 12:02:14--  https://storage.googleapis.com/esmartdata-courses-files/ml-course/orders.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.125.128, 2404:6800:4008:c03::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.125.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24680147 (24M) [application/octet-stream]
# Saving to: ‘orders.csv’
#
# orders.csv          100%[===================>]  23.54M  20.7MB/s    in 1.1s
#
# 2020-02-07 12:02:16 (20.7 MB/s) - ‘orders.csv’ saved [24680147/24680147]

# %%
import pandas as pd

pd.set_option('display.float_format', lambda x: f'{x:.2f}')

# %%
products = pd.read_csv('products.csv', usecols=['product_id', 'product_name'])
products.head()
# Out:
#    product_id                                       product_name
# 0           1                         Chocolate Sandwich Cookies
# 1           2                                   All-Seasons Salt
# 2           3               Robust Golden Unsweetened Oolong Tea
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           5                          Green Chile Anytime Sauce

# %%
orders = pd.read_csv('orders.csv', usecols=['order_id', 'product_id'])
orders.head()
# Out:
#    order_id  product_id
# 0         1       49302
# 1         1       11109
# 2         1       10246
# 3         1       49683
# 4         1       43633

# %%
data = pd.merge(orders, products, how='inner', on='product_id', sort=True)
data.head()
# Out:
#    order_id  product_id                product_name
# 0      6695           1  Chocolate Sandwich Cookies
# 1     48361           1  Chocolate Sandwich Cookies
# 2     63770           1  Chocolate Sandwich Cookies
# 3     75339           1  Chocolate Sandwich Cookies
# 4    240996           1  Chocolate Sandwich Cookies

# %%
data.describe()
# Out:
#         order_id  product_id
# count 1384617.00  1384617.00
# mean  1706297.62    25556.24
# std    989732.65    14121.27
# min         1.00        1.00
# 25%    843370.00    13380.00
# 50%   1701880.00    25298.00
# 75%   2568023.00    37940.00
# max   3421070.00    49688.00

# %%
data['product_name'].value_counts()
# Out:
# Banana                                  18726
# Bag of Organic Bananas                  15480
# Organic Strawberries                    10894
# Organic Baby Spinach                     9784
# Large Lemon                              8135
#                                         ...
# Thai Yellow Curry Sauce                     1
# Albacore Premium White In Water Tuna        1
# Loaded Baked Potato Bites                   1
# AFTER SHAVE CLASSIC                         1
# Ziti Pasta                                  1
# Name: product_name, Length: 39123, dtype: int64

# %%
data['order_id'].nunique()
# Out:
# 131209

# %%
transactions = data.groupby(by='order_id')['product_name'].apply(lambda name: ','.join(name))
transactions = transactions.str.split(',')
transactions
# Out:
# order_id
# 1          [Organic Celery Hearts, Organic 4% Milk Fat Wh...
# 36         [Spring Water, Prosciutto,  Americano, Grated ...
# 38         [Organic Raw Unfiltered Apple Cider Vinegar, S...
# 96         [Roasted Turkey, Organic Whole Strawberries, O...
# 98         [Organic Whole Grassmilk Milk, Garbanzo Beans,...
#                                  ...
# 3421049    [Organic Grated Ginger, Organic Whole Grain Wh...
# 3421056    [Total Plain Greek Strained Yogurt, Homestyle ...
# 3421058    [Extralean Ground Turkey Breast, Club Soda Low...
# 3421063    [No Salt Added Gluten-Free Blue Chips Made wit...
# 3421070    [Broccoli Florettes, Creamy Peanut Butter, Org...
# Name: product_name, Length: 131209, dtype: object

# %%
from mlxtend.preprocessing import TransactionEncoder

encoder = TransactionEncoder()
encoder.fit(transactions)
transactions_encoded = encoder.transform(transactions, sparse=True)
transactions_encoded
# Out:
# <131209x40434 sparse matrix of type '<class 'numpy.bool_'>'
# 	with 1442410 stored elements in Compressed Sparse Row format>

# %%
transactions_encoded_df = pd.DataFrame(transactions_encoded.toarray(), columns=encoder.columns_)
transactions_encoded_df
# Out:
#                ...   Lightly Seasoned with Rosemary and Roasted Garlic Family Size Herb Chicken Tortellini
# 0       False  ...                                              False
# 1       False  ...                                              False
# 2       False  ...                                              False
# 3       False  ...                                              False
# 4       False  ...                                              False
# ...       ...  ...                                                ...
# 131204  False  ...                                              False
# 131205  False  ...                                              False
# 131206  False  ...                                              False
# 131207  False  ...                                              False
# 131208  False  ...                                              False
#
# [131209 rows x 40434 columns]

# %%
from mlxtend.frequent_patterns import apriori, association_rules

supports = apriori(transactions_encoded_df, min_support=0.01, use_colnames=True, n_jobs=-1)
supports
# Out:
#      support                                      itemsets
# 0       0.01                                        ( Bag)
# 1       0.01                                      ( Bunch)
# 2       0.02                                    ( Organic)
# 3       0.02                      (100% Whole Wheat Bread)
# 4       0.01                         (2% Reduced Fat Milk)
# ..       ...                                           ...
# 119     0.01                (Organic Avocado, Large Lemon)
# 120     0.01       (Organic Avocado, Organic Baby Spinach)
# 121     0.01  (Organic Strawberries, Organic Baby Spinach)
# 122     0.01  (Organic Hass Avocado, Organic Strawberries)
# 123     0.01   (Organic Raspberries, Organic Strawberries)
#
# [124 rows x 2 columns]

# %%
rules = association_rules(supports, metric='confidence', min_threshold=0)
rules = rules.iloc[:, [0, 1, 4, 5]]
rules = rules.sort_values(by='confidence', ascending=False)
rules
# Out:
#                  antecedents               consequents  support  confidence
# 0                     ( Bag)             (Clementines)     0.01        0.79
# 1              (Clementines)                    ( Bag)     0.01        0.52
# 5     (Organic Hass Avocado)  (Bag of Organic Bananas)     0.02        0.33
# 6      (Organic Raspberries)  (Bag of Organic Bananas)     0.01        0.32
# 32     (Organic Raspberries)    (Organic Strawberries)     0.01        0.30
# 20            (Strawberries)                  (Banana)     0.01        0.30
# 14         (Organic Avocado)                  (Banana)     0.02        0.30
# 9     (Organic Strawberries)  (Bag of Organic Bananas)     0.02        0.28
# 11             (Large Lemon)                  (Banana)     0.02        0.27
# 22                   (Limes)             (Large Lemon)     0.01        0.26
# 3     (Organic Baby Spinach)  (Bag of Organic Bananas)     0.02        0.23
# 12                   (Limes)                  (Banana)     0.01        0.22
# 30    (Organic Hass Avocado)    (Organic Strawberries)     0.01        0.21
# 17    (Organic Baby Spinach)                  (Banana)     0.02        0.20
# 19    (Organic Strawberries)                  (Banana)     0.02        0.20
# 8   (Bag of Organic Bananas)    (Organic Strawberries)     0.02        0.20
# 23             (Large Lemon)                   (Limes)     0.01        0.20
# 26         (Organic Avocado)    (Organic Baby Spinach)     0.01        0.19
# 24         (Organic Avocado)             (Large Lemon)     0.01        0.18
# 29    (Organic Baby Spinach)    (Organic Strawberries)     0.01        0.17
# 25             (Large Lemon)         (Organic Avocado)     0.01        0.17
# 4   (Bag of Organic Bananas)    (Organic Hass Avocado)     0.02        0.16
# 33    (Organic Strawberries)     (Organic Raspberries)     0.01        0.15
# 28    (Organic Strawberries)    (Organic Baby Spinach)     0.01        0.15
# 2   (Bag of Organic Bananas)    (Organic Baby Spinach)     0.02        0.14
# 27    (Organic Baby Spinach)         (Organic Avocado)     0.01        0.14
# 31    (Organic Strawberries)    (Organic Hass Avocado)     0.01        0.14
# 15                  (Banana)         (Organic Avocado)     0.02        0.12
# 18                  (Banana)    (Organic Strawberries)     0.02        0.12
# 10                  (Banana)             (Large Lemon)     0.02        0.12
# 7   (Bag of Organic Bananas)     (Organic Raspberries)     0.01        0.11
# 16                  (Banana)    (Organic Baby Spinach)     0.02        0.11
# 21                  (Banana)            (Strawberries)     0.01        0.10
# 13                  (Banana)                   (Limes)     0.01        0.07
